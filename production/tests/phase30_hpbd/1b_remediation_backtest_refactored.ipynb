# %% [markdown]
# # ============================================================================
# # Aureus Sigma Capital - Phase 29b: Remediation Strategy Backtest (Refactored)
# # Notebook: 29b_remediation_backtest_refactored.ipynb
# #
# # Objective:
# #   To conduct a comparative backtest between the canonical "Aggressive Growth"
# #   strategy and a "Remediation" strategy. The remediation strategy aims to
# #   improve the risk profile by introducing a beta constraint and score-based
# #   weighting. This notebook uses the production-grade backtesting engine and
# #   generates a full comparative performance report.
# #
# # Strategies Compared:
# #   1.  **Canonical Baseline:** Equal-weighted top quintile portfolio.
# #   2.  **R1 Remediation:** Score-weighted, beta-constrained (target < 0.9) portfolio.
# # ============================================================================

# %%
# ============================================================================
# CELL 1: SETUP & CONFIGURATION
# ============================================================================

# --- Core Libraries ---
import pandas as pd
import numpy as np
import logging
from pathlib import Path
import sys
import yaml

# --- Visualization ---
import matplotlib.pyplot as plt
import seaborn as sns

# --- Database ---
from sqlalchemy import create_engine, text

# --- Environment Setup ---
# %load_ext autoreload
# %autoreload 2
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')
sns.set(style='whitegrid', palette='deep')

# --- Add Project Root to Python Path ---
try:
    project_root = Path.cwd().parent.parent
    if str(project_root) not in sys.path: sys.path.insert(0, str(project_root))
    print(f"✅ Project root successfully set to: {project_root}")
except Exception:
    project_root = Path.cwd() # Fallback for different environments
    if str(project_root) not in sys.path: sys.path.insert(0, str(project_root))
    print(f"✅ Project root (fallback) set to: {project_root}")

# --- Import Production Modules ---
try:
    from production.backtesting.vectorized_engine import VectorizedEngine
    from production.backtesting.strategy_constructors import equal_weight_top_quintile, score_weighted_beta_constrained
    from production.utils.db import create_db_connection, load_all_data_for_backtest
    from production.utils.reporting import calculate_official_metrics # Use the official calculator
    print("✅ Successfully imported production modules.")
except ImportError as e:
    print(f"❌ ERROR: Could not import production modules: {e}")
    raise

# --- Base Configuration (shared by both backtests) ---
BASE_CONFIG = {
    "backtest_start_date": "2020-01-01",
    "backtest_end_date": "2025-07-31",
    "rebalance_frequency": "M",
    "transaction_cost_bps": 30,
    "universe": {
        "lookback_days": 63, "adtv_threshold_bn": 10.0,
        "top_n": 200, "min_trading_coverage": 0.6,
    },
    "signal": {"db_strategy_version": "qvm_v2.1.1_flat"},
    "portfolio": { "selection_percentile": 0.8 }
}

# --- Configuration for the Canonical Baseline ---
BASELINE_CONFIG = BASE_CONFIG.copy()
BASELINE_CONFIG['strategy_name'] = "Aureus_Sigma_Vietnam_Aggressive_Growth"

# --- Configuration for the R1 Remediation Strategy ---
REMEDIATION_CONFIG = BASE_CONFIG.copy()
REMEDIATION_CONFIG['strategy_name'] = "Aureus_Sigma_R1_Remediation"
REMEDIATION_CONFIG['portfolio'] = {
    **REMEDIATION_CONFIG['portfolio'],
    "beta_target": 0.90,
    "beta_estimation_window": 126, # Approx 6 months
    "max_weight": 0.08 # 8% max weight per stock
}

print("\n⚙️  Strategy configurations loaded successfully.")

# --- Database Connection ---
db_engine = create_db_connection(project_root)
if db_engine is None: raise ConnectionError("Database connection failed, cannot proceed.")
# Out:
# ✅ Project root successfully set to: /Users/ducnguyen/Library/CloudStorage/GoogleDrive-duc.nguyentcb@gmail.com/My Drive/quant-world-invest/factor_investing_project
# 2025-08-07 16:39:15,007 - INFO - Database connection established successfully to schema 'alphabeta'.
# ✅ Successfully imported production modules.
#
# ⚙️  Strategy configurations loaded successfully.

# %%
# ============================================================================
# CELL 2: DATA INGESTION
# ============================================================================

try:
    factor_data_raw, daily_returns_matrix, benchmark_returns = load_all_data_for_backtest(
        config=BASE_CONFIG, db_engine=db_engine
    )
    print("\n✅ Data ingestion complete. Backtest-ready data is now in memory.")
except Exception as e:
    print(f"❌ An error occurred during data ingestion: {e}")
    raise
# Out:
# 2025-08-07 16:39:17,530 - INFO - Loading all data for period: 2019-10-01 to 2025-07-31...
# 2025-08-07 16:39:26,365 - INFO - Loaded 1,014,799 factor score rows for version 'qvm_v2.1.1_flat'.
# 2025-08-07 16:39:30,633 - INFO - Loaded 1,035,599 daily price records.
# 2025-08-07 16:39:30,665 - INFO - Loaded 1,458 VN-Index records.
# 2025-08-07 16:39:30,665 - INFO - Preparing data for backtesting engine...
# 2025-08-07 16:39:31,134 - INFO - Created daily returns matrix with shape: (1458, 728)
# 2025-08-07 16:39:31,136 - INFO - Prepared benchmark returns series with 1458 data points.
# ✅ Data ingestion complete. Backtest-ready data is now in memory.

# %%
# ============================================================================
# CELL 3: BACKTEST EXECUTION
# ============================================================================

def run_comparative_backtests(base_config, baseline_specific_config, remediation_specific_config, data_pack, db_conn):
    """Orchestrates the execution of both baseline and remediation backtests."""
    factor_data, returns_matrix, bench_returns = data_pack
    
    # 1. Instantiate the single, unified engine
    engine = VectorizedEngine(
        config=base_config,
        factor_data=factor_data,
        returns_matrix=returns_matrix,
        benchmark_returns=bench_returns,
        db_engine=db_conn
    )
    print(f"✅ VectorizedEngine initialized for backtest period: {base_config['backtest_start_date']} to {base_config['backtest_end_date']}")

    # 2. Run the CANONICAL BASELINE backtest
    print("\n" + "="*80)
    logging.info("RUNNING CANONICAL BASELINE BACKTEST...")
    engine.config.update(baseline_specific_config)
    baseline_returns, baseline_diags = engine.run_backtest(
        portfolio_constructor=equal_weight_top_quintile
    )
    print(f"✅ Canonical Baseline backtest complete.")

    # 3. Run the R1 REMEDIATION backtest
    print("\n" + "="*80)
    logging.info("RUNNING R1 REMEDIATION BACKTEST...")
    engine.config.update(remediation_specific_config)
    remediation_returns, remediation_diags = engine.run_backtest(
        portfolio_constructor=score_weighted_beta_constrained
    )
    print(f"✅ R1 Remediation backtest complete.")

    return (baseline_returns, baseline_diags), (remediation_returns, remediation_diags)

# %%
# ============================================================================
# CELL 4: COMPARATIVE PERFORMANCE REPORTING SUITE
# ============================================================================

def generate_comparison_tearsheet(
    baseline_returns: pd.Series,
    remediation_returns: pd.Series,
    benchmark_returns: pd.Series,
    baseline_diags: pd.DataFrame,
    remediation_diags: pd.DataFrame,
    title: str
):
    """Generates a comprehensive tearsheet comparing two strategies against a benchmark."""
    print("\n" + "="*80)
    print("📊 GENERATING COMPARATIVE PERFORMANCE REPORT...")
    print("="*80)

    # --- Align data to the first trade date of the baseline ---
    first_trade_date = baseline_returns.loc[baseline_returns.ne(0)].index.min()
    b_ret = baseline_returns.loc[first_trade_date:].rename("Baseline")
    r_ret = remediation_returns.loc[first_trade_date:].rename("Remediation")
    bench_ret = benchmark_returns.loc[first_trade_date:].rename("VN-Index")

    # --- Calculate Metrics ---
    baseline_metrics = calculate_official_metrics(b_ret, bench_ret)
    remediation_metrics = calculate_official_metrics(r_ret, bench_ret)
    benchmark_metrics = calculate_official_metrics(bench_ret, bench_ret)
    
    summary_df = pd.DataFrame({
        'Baseline (Aggressive Growth)': baseline_metrics,
        'R1 Remediation (Beta-Constrained)': remediation_metrics,
        'VN-Index': benchmark_metrics
    }).T

    # --- Create Figure ---
    fig = plt.figure(figsize=(18, 28))
    gs = fig.add_gridspec(5, 2, height_ratios=[1.2, 0.8, 0.8, 0.8, 1.0], hspace=0.6, wspace=0.25)
    fig.suptitle(title, fontsize=24, fontweight='bold', y=0.98)

    # 1. Cumulative Performance
    ax1 = fig.add_subplot(gs[0, :])
    (1 + b_ret).cumprod().plot(ax=ax1, label='Baseline (Aggressive)', color='#3498DB', lw=2.5)
    (1 + r_ret).cumprod().plot(ax=ax1, label='Remediation (Beta-Constrained)', color='#1ABC9C', lw=2.5)
    (1 + bench_ret).cumprod().plot(ax=ax1, label='VN-Index', color='#34495E', linestyle='--', lw=2)
    ax1.set_title('Cumulative Performance (Log Scale)', fontweight='bold', fontsize=14)
    ax1.set_ylabel('Growth of 1 VND'); ax1.set_yscale('log'); ax1.legend(loc='upper left'); ax1.grid(True, which='both', linestyle='--', alpha=0.6)

    # 2. Drawdown Analysis
    ax2_l = fig.add_subplot(gs[1, 0])
    dd_b = ((1 + b_ret).cumprod() / (1 + b_ret).cumprod().cummax() - 1) * 100
    dd_b.plot(ax=ax2_l, color='#C0392B', label='Baseline Drawdown')
    ax2_l.fill_between(dd_b.index, dd_b, 0, color='#C0392B', alpha=0.1)
    ax2_l.set_title('Baseline Drawdown', fontweight='bold', fontsize=14)
    ax2_l.set_ylabel('Drawdown (%)'); ax2_l.grid(True, linestyle='--', alpha=0.5)

    ax2_r = fig.add_subplot(gs[1, 1])
    dd_r = ((1 + r_ret).cumprod() / (1 + r_ret).cumprod().cummax() - 1) * 100
    dd_r.plot(ax=ax2_r, color='#E67E22', label='Remediation Drawdown')
    ax2_r.fill_between(dd_r.index, dd_r, 0, color='#E67E22', alpha=0.1)
    ax2_r.set_title('Remediation Drawdown', fontweight='bold', fontsize=14)
    ax2_r.grid(True, linestyle='--', alpha=0.5)

    # 3. Annual Returns
    ax3 = fig.add_subplot(gs[2, :])
    annual_returns = pd.DataFrame({
        'Baseline': b_ret.resample('Y').apply(lambda x: (1+x).prod()-1) * 100,
        'Remediation': r_ret.resample('Y').apply(lambda x: (1+x).prod()-1) * 100,
        'VN-Index': bench_ret.resample('Y').apply(lambda x: (1+x).prod()-1) * 100
    })
    annual_returns.plot(kind='bar', ax=ax3, color=['#3498DB', '#1ABC9C', '#34495E'])
    ax3.set_xticklabels([d.strftime('%Y') for d in annual_returns.index], rotation=45, ha='right')
    ax3.set_title('Annual Returns Comparison', fontweight='bold', fontsize=14)
    ax3.set_ylabel('Return (%)'); ax3.grid(True, axis='y', linestyle='--', alpha=0.6)

    # 4. Diagnostics: Turnover
    ax4 = fig.add_subplot(gs[3, :])
    baseline_diags['turnover'].plot(ax=ax4, label='Baseline Turnover', color='#3498DB', marker='.', markersize=4, linestyle='--')
    remediation_diags['turnover'].plot(ax=ax4, label='Remediation Turnover', color='#1ABC9C', marker='.', markersize=4, linestyle='--')
    ax4.set_title('Monthly Portfolio Turnover', fontweight='bold', fontsize=14)
    ax4.set_ylabel('Turnover Ratio'); ax4.legend(); ax4.grid(True, linestyle='--', alpha=0.5)

    # 5. Performance Metrics Table
    ax5 = fig.add_subplot(gs[4, :]); ax5.axis('off')
    summary_data = [[col] + summary_df[col].apply('{:,.2f}'.format).tolist() for col in summary_df.columns]
    table_data = list(zip(*summary_data))
    col_labels = ['Metric'] + list(summary_df.index)
    table = ax5.table(cellText=table_data, colLabels=col_labels, loc='center', cellLoc='center')
    table.auto_set_font_size(False); table.set_fontsize(12); table.scale(1, 2.8)
    for (row, col), cell in table.get_celld().items():
        if row == 0 or col == 0: cell.set_text_props(fontweight='bold')
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.96])
    plt.show()

# %%
# ============================================================================
# CELL 4: COMPARATIVE PERFORMANCE REPORTING SUITE (CORRECTED)
# ============================================================================

def generate_comparison_tearsheet(
    baseline_returns: pd.Series,
    remediation_returns: pd.Series,
    benchmark_returns: pd.Series,
    baseline_diags: pd.DataFrame,
    remediation_diags: pd.DataFrame,
    title: str
):
    """Generates a comprehensive tearsheet comparing two strategies against a benchmark."""
    print("\n" + "="*80)
    print("📊 GENERATING COMPARATIVE PERFORMANCE REPORT...")
    print("="*80)

    # --- Align data to the first trade date of the baseline ---
    first_trade_date = baseline_returns.loc[baseline_returns.ne(0)].index.min()
    if pd.isna(first_trade_date):
        print("⚠️ Cannot generate report: No trades were made in the baseline strategy.")
        return

    b_ret = baseline_returns.loc[first_trade_date:].rename("Baseline")
    r_ret = remediation_returns.loc[first_trade_date:].rename("Remediation")
    bench_ret = benchmark_returns.loc[first_trade_date:].rename("VN-Index")

    # --- Calculate Metrics ---
    baseline_metrics = calculate_official_metrics(b_ret, bench_ret)
    remediation_metrics = calculate_official_metrics(r_ret, bench_ret)
    benchmark_metrics = calculate_official_metrics(bench_ret, bench_ret)
    
    summary_df = pd.DataFrame({
        'Baseline (Aggressive Growth)': baseline_metrics,
        'R1 Remediation (Beta-Constrained)': remediation_metrics,
        'VN-Index': benchmark_metrics
    }).T

    # --- Create Figure ---
    fig = plt.figure(figsize=(18, 28))
    gs = fig.add_gridspec(5, 2, height_ratios=[1.2, 0.8, 0.8, 0.8, 1.0], hspace=0.6, wspace=0.25)
    fig.suptitle(title, fontsize=24, fontweight='bold', y=0.98)

    # 1. Cumulative Performance
    ax1 = fig.add_subplot(gs[0, :])
    (1 + b_ret).cumprod().plot(ax=ax1, label='Baseline (Aggressive)', color='#3498DB', lw=2.5)
    (1 + r_ret).cumprod().plot(ax=ax1, label='Remediation (Beta-Constrained)', color='#1ABC9C', lw=2.5)
    (1 + bench_ret).cumprod().plot(ax=ax1, label='VN-Index', color='#34495E', linestyle='--', lw=2)
    ax1.set_title('Cumulative Performance (Log Scale)', fontweight='bold', fontsize=14)
    ax1.set_ylabel('Growth of 1 VND'); ax1.set_yscale('log'); ax1.legend(loc='upper left'); ax1.grid(True, which='both', linestyle='--', alpha=0.6)

    # 2. Drawdown Analysis
    ax2_l = fig.add_subplot(gs[1, 0])
    dd_b = ((1 + b_ret).cumprod() / (1 + b_ret).cumprod().cummax() - 1) * 100
    dd_b.plot(ax=ax2_l, color='#C0392B', label='Baseline Drawdown')
    ax2_l.fill_between(dd_b.index, dd_b, 0, color='#C0392B', alpha=0.1)
    ax2_l.set_title('Baseline Drawdown', fontweight='bold', fontsize=14)
    ax2_l.set_ylabel('Drawdown (%)'); ax2_l.grid(True, linestyle='--', alpha=0.5)

    ax2_r = fig.add_subplot(gs[1, 1])
    dd_r = ((1 + r_ret).cumprod() / (1 + r_ret).cumprod().cummax() - 1) * 100
    dd_r.plot(ax=ax2_r, color='#E67E22', label='Remediation Drawdown')
    ax2_r.fill_between(dd_r.index, dd_r, 0, color='#E67E22', alpha=0.1)
    ax2_r.set_title('Remediation Drawdown', fontweight='bold', fontsize=14)
    ax2_r.grid(True, linestyle='--', alpha=0.5)

    # 3. Annual Returns
    ax3 = fig.add_subplot(gs[2, :])
    annual_returns = pd.DataFrame({
        'Baseline': b_ret.resample('Y').apply(lambda x: (1+x).prod()-1) * 100,
        'Remediation': r_ret.resample('Y').apply(lambda x: (1+x).prod()-1) * 100,
        'VN-Index': bench_ret.resample('Y').apply(lambda x: (1+x).prod()-1) * 100
    })
    annual_returns.plot(kind='bar', ax=ax3, color=['#3498DB', '#1ABC9C', '#34495E'])
    ax3.set_xticklabels([d.strftime('%Y') for d in annual_returns.index], rotation=45, ha='right')
    ax3.set_title('Annual Returns Comparison', fontweight='bold', fontsize=14)
    ax3.set_ylabel('Return (%)'); ax3.grid(True, axis='y', linestyle='--', alpha=0.6)

    # 4. Diagnostics: Turnover
    ax4 = fig.add_subplot(gs[3, :])
    baseline_diags['turnover'].plot(ax=ax4, label='Baseline Turnover', color='#3498DB', marker='.', markersize=4, linestyle='--')
    remediation_diags['turnover'].plot(ax=ax4, label='Remediation Turnover', color='#1ABC9C', marker='.', markersize=4, linestyle='--')
    ax4.set_title('Monthly Portfolio Turnover', fontweight='bold', fontsize=14)
    ax4.set_ylabel('Turnover Ratio'); ax4.legend(); ax4.grid(True, linestyle='--', alpha=0.5)

    # 5. Performance Metrics Table (FIXED LOGIC)
    ax5 = fig.add_subplot(gs[4, :]); ax5.axis('off')
    
    # Define the column headers for the table
    col_labels = ['Metric'] + list(summary_df.index)
    
    # Create the table rows. Each inner list is one row in the table.
    # Format: [MetricName, ValueForStrategy1, ValueForStrategy2, ...]
    table_rows = [
        [metric] + summary_df.loc[:, metric].apply('{:,.2f}'.format).tolist()
        for metric in summary_df.columns
    ]
    
    # Create the matplotlib table with the correctly shaped data
    table = ax5.table(
        cellText=table_rows,
        colLabels=col_labels,
        loc='center',
        cellLoc='center'
    )
    table.auto_set_font_size(False); table.set_fontsize(12); table.scale(1, 2.8)
    
    # Style the header and first column
    for (row, col), cell in table.get_celld().items():
        if row == 0 or col == 0:
            cell.set_text_props(fontweight='bold')
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.96])
    plt.show()

# %%
# ============================================================================
# CELL 5: EXECUTION & REPORT GENERATION
# ============================================================================

# --- Execute Backtests ---
(baseline_returns, baseline_diags), (remediation_returns, remediation_diags) = run_comparative_backtests(
    base_config=BASE_CONFIG,
    baseline_specific_config=BASELINE_CONFIG,
    remediation_specific_config=REMEDIATION_CONFIG,
    data_pack=(factor_data_raw, daily_returns_matrix, benchmark_returns),
    db_conn=db_engine
)

# --- Generate Final Report ---
generate_comparison_tearsheet(
    baseline_returns=baseline_returns,
    remediation_returns=remediation_returns,
    benchmark_returns=benchmark_returns,
    baseline_diags=baseline_diags,
    remediation_diags=remediation_diags,
    title="Official Backtest: Aggressive Growth vs. R1 Remediation (Beta-Constrained)"
)
# Out:
# 2025-08-07 16:53:46,061 - INFO - VectorizedEngine initialized for backtest: Aureus_Sigma_R1_Remediation
# 2025-08-07 16:53:46,062 - INFO - Backtest Period: 2020-01-01 to 2025-07-31
# 2025-08-07 16:53:46,063 - INFO - RUNNING CANONICAL BASELINE BACKTEST...
# 2025-08-07 16:53:46,063 - INFO - Starting backtest execution with constructor: equal_weight_top_quintile
# 2025-08-07 16:53:46,070 - INFO - Generated 67 rebalance dates with frequency 'M'.
# 2025-08-07 16:53:46,075 - INFO - Constructing universe for 2020-01-31 using data from 2019-11-29 to 2020-01-30.
# ✅ VectorizedEngine initialized for backtest period: 2020-01-01 to 2025-07-31
#
# ================================================================================
# 2025-08-07 16:53:46,684 - INFO - Found 661 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:53:50,175 - INFO - Initial metrics calculated for 661 tickers. Applying filters...
# 2025-08-07 16:53:50,177 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:53:50,178 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:53:50,182 - INFO - 82 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:53:50,196 - INFO - Final universe DataFrame constructed for 82 stocks with sector data.
# 2025-08-07 16:53:50,216 - INFO - Constructing universe for 2020-02-28 using data from 2019-12-27 to 2020-02-27.
# 2025-08-07 16:53:50,405 - INFO - Found 666 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:53:52,937 - INFO - Initial metrics calculated for 666 tickers. Applying filters...
# 2025-08-07 16:53:52,937 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:53:52,938 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:53:52,938 - INFO - 71 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:53:52,944 - INFO - Final universe DataFrame constructed for 71 stocks with sector data.
# 2025-08-07 16:53:52,951 - INFO - Constructing universe for 2020-03-31 using data from 2020-01-28 to 2020-03-30.
# 2025-08-07 16:53:53,053 - INFO - Found 674 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:53:55,125 - INFO - Initial metrics calculated for 674 tickers. Applying filters...
# 2025-08-07 16:53:55,125 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:53:55,126 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:53:55,127 - INFO - 79 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:53:55,132 - INFO - Final universe DataFrame constructed for 79 stocks with sector data.
# 2025-08-07 16:53:55,137 - INFO - Constructing universe for 2020-04-29 using data from 2020-02-26 to 2020-04-28.
# 2025-08-07 16:53:55,431 - INFO - Found 676 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:53:57,972 - INFO - Initial metrics calculated for 676 tickers. Applying filters...
# 2025-08-07 16:53:57,972 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:53:57,973 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:53:57,974 - INFO - 86 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:53:57,982 - INFO - Final universe DataFrame constructed for 86 stocks with sector data.
# 2025-08-07 16:53:57,991 - INFO - Constructing universe for 2020-05-29 using data from 2020-03-27 to 2020-05-28.
# 2025-08-07 16:53:58,099 - INFO - Found 673 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:01,079 - INFO - Initial metrics calculated for 673 tickers. Applying filters...
# 2025-08-07 16:54:01,085 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:01,086 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:01,089 - INFO - 95 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:01,116 - INFO - Final universe DataFrame constructed for 95 stocks with sector data.
# 2025-08-07 16:54:01,143 - INFO - Constructing universe for 2020-06-30 using data from 2020-04-28 to 2020-06-29.
# 2025-08-07 16:54:01,356 - INFO - Found 676 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:05,340 - INFO - Initial metrics calculated for 676 tickers. Applying filters...
# 2025-08-07 16:54:05,341 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:05,342 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:05,343 - INFO - 115 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:05,354 - INFO - Final universe DataFrame constructed for 115 stocks with sector data.
# 2025-08-07 16:54:05,362 - INFO - Constructing universe for 2020-07-31 using data from 2020-05-29 to 2020-07-30.
# 2025-08-07 16:54:05,573 - INFO - Found 683 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:09,305 - INFO - Initial metrics calculated for 683 tickers. Applying filters...
# 2025-08-07 16:54:09,306 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:09,306 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:09,307 - INFO - 108 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:09,316 - INFO - Final universe DataFrame constructed for 108 stocks with sector data.
# 2025-08-07 16:54:09,324 - INFO - Constructing universe for 2020-08-31 using data from 2020-06-29 to 2020-08-30.
# 2025-08-07 16:54:09,468 - INFO - Found 685 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:14,090 - INFO - Initial metrics calculated for 685 tickers. Applying filters...
# 2025-08-07 16:54:14,091 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:14,091 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:14,092 - INFO - 103 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:14,099 - INFO - Final universe DataFrame constructed for 103 stocks with sector data.
# 2025-08-07 16:54:14,106 - INFO - Constructing universe for 2020-09-30 using data from 2020-07-29 to 2020-09-29.
# 2025-08-07 16:54:14,370 - INFO - Found 685 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:17,808 - INFO - Initial metrics calculated for 685 tickers. Applying filters...
# 2025-08-07 16:54:17,810 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:17,810 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:17,815 - INFO - 118 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:17,829 - INFO - Final universe DataFrame constructed for 118 stocks with sector data.
# 2025-08-07 16:54:17,845 - INFO - Constructing universe for 2020-10-30 using data from 2020-08-28 to 2020-10-29.
# 2025-08-07 16:54:17,997 - INFO - Found 684 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:21,133 - INFO - Initial metrics calculated for 684 tickers. Applying filters...
# 2025-08-07 16:54:21,133 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:21,133 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:21,134 - INFO - 123 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:21,143 - INFO - Final universe DataFrame constructed for 123 stocks with sector data.
# 2025-08-07 16:54:21,149 - INFO - Constructing universe for 2020-11-30 using data from 2020-09-28 to 2020-11-29.
# 2025-08-07 16:54:21,296 - INFO - Found 686 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:23,807 - INFO - Initial metrics calculated for 686 tickers. Applying filters...
# 2025-08-07 16:54:23,808 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:23,808 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:23,809 - INFO - 125 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:23,816 - INFO - Final universe DataFrame constructed for 125 stocks with sector data.
# 2025-08-07 16:54:23,822 - INFO - Constructing universe for 2020-12-31 using data from 2020-10-29 to 2020-12-30.
# 2025-08-07 16:54:23,937 - INFO - Found 695 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:27,471 - INFO - Initial metrics calculated for 695 tickers. Applying filters...
# 2025-08-07 16:54:27,476 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:27,476 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:27,478 - INFO - 150 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:27,490 - INFO - Final universe DataFrame constructed for 150 stocks with sector data.
# 2025-08-07 16:54:27,502 - INFO - Constructing universe for 2021-01-29 using data from 2020-11-27 to 2021-01-28.
# 2025-08-07 16:54:27,817 - INFO - Found 704 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:30,882 - INFO - Initial metrics calculated for 704 tickers. Applying filters...
# 2025-08-07 16:54:30,882 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:30,882 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:30,883 - INFO - 170 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:30,891 - INFO - Final universe DataFrame constructed for 170 stocks with sector data.
# 2025-08-07 16:54:30,897 - INFO - Constructing universe for 2021-02-26 using data from 2020-12-25 to 2021-02-25.
# 2025-08-07 16:54:31,118 - INFO - Found 707 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:34,976 - INFO - Initial metrics calculated for 707 tickers. Applying filters...
# 2025-08-07 16:54:34,979 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:34,979 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:34,981 - INFO - 171 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:34,993 - INFO - Final universe DataFrame constructed for 171 stocks with sector data.
# 2025-08-07 16:54:35,009 - INFO - Constructing universe for 2021-03-31 using data from 2021-01-27 to 2021-03-30.
# 2025-08-07 16:54:35,230 - INFO - Found 707 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:38,846 - INFO - Initial metrics calculated for 707 tickers. Applying filters...
# 2025-08-07 16:54:38,849 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:38,849 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:38,851 - INFO - 168 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:38,875 - INFO - Final universe DataFrame constructed for 168 stocks with sector data.
# 2025-08-07 16:54:38,890 - INFO - Constructing universe for 2021-04-29 using data from 2021-02-25 to 2021-04-28.
# 2025-08-07 16:54:39,135 - INFO - Found 709 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:42,471 - INFO - Initial metrics calculated for 709 tickers. Applying filters...
# 2025-08-07 16:54:42,472 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:42,473 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:42,476 - INFO - 181 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:42,483 - INFO - Final universe DataFrame constructed for 181 stocks with sector data.
# 2025-08-07 16:54:42,492 - INFO - Constructing universe for 2021-05-31 using data from 2021-03-29 to 2021-05-30.
# 2025-08-07 16:54:42,630 - INFO - Found 710 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:46,670 - INFO - Initial metrics calculated for 710 tickers. Applying filters...
# 2025-08-07 16:54:46,674 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:46,674 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:46,678 - INFO - 180 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:46,693 - INFO - Final universe DataFrame constructed for 180 stocks with sector data.
# 2025-08-07 16:54:46,706 - INFO - Constructing universe for 2021-06-30 using data from 2021-04-28 to 2021-06-29.
# 2025-08-07 16:54:46,926 - INFO - Found 710 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:50,246 - INFO - Initial metrics calculated for 710 tickers. Applying filters...
# 2025-08-07 16:54:50,246 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:50,246 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:50,247 - INFO - 184 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:50,255 - INFO - Final universe DataFrame constructed for 184 stocks with sector data.
# 2025-08-07 16:54:50,261 - INFO - Constructing universe for 2021-07-30 using data from 2021-05-28 to 2021-07-29.
# 2025-08-07 16:54:50,371 - INFO - Found 712 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:53,033 - INFO - Initial metrics calculated for 712 tickers. Applying filters...
# 2025-08-07 16:54:53,033 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:53,034 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:53,035 - INFO - 185 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:53,040 - INFO - Final universe DataFrame constructed for 185 stocks with sector data.
# 2025-08-07 16:54:53,046 - INFO - Constructing universe for 2021-08-31 using data from 2021-06-29 to 2021-08-30.
# 2025-08-07 16:54:53,191 - INFO - Found 713 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:55,489 - INFO - Initial metrics calculated for 713 tickers. Applying filters...
# 2025-08-07 16:54:55,490 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:55,491 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:55,492 - INFO - 195 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:55,505 - INFO - Final universe DataFrame constructed for 195 stocks with sector data.
# 2025-08-07 16:54:55,518 - INFO - Constructing universe for 2021-09-30 using data from 2021-07-29 to 2021-09-29.
# 2025-08-07 16:54:55,624 - INFO - Found 715 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:57,386 - INFO - Initial metrics calculated for 715 tickers. Applying filters...
# 2025-08-07 16:54:57,386 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:57,386 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:57,387 - INFO - 234 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:57,393 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:54:57,398 - INFO - Constructing universe for 2021-10-29 using data from 2021-08-27 to 2021-10-28.
# 2025-08-07 16:54:57,498 - INFO - Found 716 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:54:59,246 - INFO - Initial metrics calculated for 716 tickers. Applying filters...
# 2025-08-07 16:54:59,246 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:54:59,247 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:54:59,249 - INFO - 255 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:54:59,258 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:54:59,266 - INFO - Constructing universe for 2021-11-30 using data from 2021-09-28 to 2021-11-29.
# 2025-08-07 16:54:59,372 - INFO - Found 717 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:02,348 - INFO - Initial metrics calculated for 717 tickers. Applying filters...
# 2025-08-07 16:55:02,350 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:02,350 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:02,354 - INFO - 274 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:02,373 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:55:02,396 - INFO - Constructing universe for 2021-12-31 using data from 2021-10-29 to 2021-12-30.
# 2025-08-07 16:55:02,575 - INFO - Found 719 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:07,164 - INFO - Initial metrics calculated for 719 tickers. Applying filters...
# 2025-08-07 16:55:07,170 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:07,171 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:07,176 - INFO - 277 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:07,193 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:55:07,213 - INFO - Constructing universe for 2022-01-28 using data from 2021-11-26 to 2022-01-27.
# 2025-08-07 16:55:07,485 - INFO - Found 721 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:11,396 - INFO - Initial metrics calculated for 721 tickers. Applying filters...
# 2025-08-07 16:55:11,400 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:11,400 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:11,403 - INFO - 261 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:11,421 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:55:11,434 - INFO - Constructing universe for 2022-02-28 using data from 2021-12-27 to 2022-02-27.
# 2025-08-07 16:55:11,612 - INFO - Found 719 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:15,228 - INFO - Initial metrics calculated for 719 tickers. Applying filters...
# 2025-08-07 16:55:15,231 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:15,231 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:15,234 - INFO - 245 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:15,249 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:55:15,258 - INFO - Constructing universe for 2022-03-31 using data from 2022-01-27 to 2022-03-30.
# 2025-08-07 16:55:15,444 - INFO - Found 718 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:18,765 - INFO - Initial metrics calculated for 718 tickers. Applying filters...
# 2025-08-07 16:55:18,766 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:18,766 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:18,767 - INFO - 256 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:18,774 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:55:18,778 - INFO - Constructing universe for 2022-04-29 using data from 2022-02-25 to 2022-04-28.
# 2025-08-07 16:55:18,905 - INFO - Found 720 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:21,716 - INFO - Initial metrics calculated for 720 tickers. Applying filters...
# 2025-08-07 16:55:21,718 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:21,719 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:21,721 - INFO - 247 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:21,731 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:55:21,743 - INFO - Constructing universe for 2022-05-31 using data from 2022-03-29 to 2022-05-30.
# 2025-08-07 16:55:21,887 - INFO - Found 719 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:25,860 - INFO - Initial metrics calculated for 719 tickers. Applying filters...
# 2025-08-07 16:55:25,861 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:25,862 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:25,864 - INFO - 202 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:25,890 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:55:25,919 - INFO - Constructing universe for 2022-06-30 using data from 2022-04-28 to 2022-06-29.
# 2025-08-07 16:55:26,169 - INFO - Found 720 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:29,471 - INFO - Initial metrics calculated for 720 tickers. Applying filters...
# 2025-08-07 16:55:29,472 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:29,472 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:29,473 - INFO - 180 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:29,480 - INFO - Final universe DataFrame constructed for 180 stocks with sector data.
# 2025-08-07 16:55:29,485 - INFO - Constructing universe for 2022-07-29 using data from 2022-05-27 to 2022-07-28.
# 2025-08-07 16:55:29,593 - INFO - Found 720 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:32,789 - INFO - Initial metrics calculated for 720 tickers. Applying filters...
# 2025-08-07 16:55:32,793 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:32,794 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:32,796 - INFO - 164 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:32,823 - INFO - Final universe DataFrame constructed for 164 stocks with sector data.
# 2025-08-07 16:55:32,855 - INFO - Constructing universe for 2022-08-31 using data from 2022-06-29 to 2022-08-30.
# 2025-08-07 16:55:33,073 - INFO - Found 721 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:36,738 - INFO - Initial metrics calculated for 721 tickers. Applying filters...
# 2025-08-07 16:55:36,739 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:36,740 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:36,744 - INFO - 174 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:36,759 - INFO - Final universe DataFrame constructed for 174 stocks with sector data.
# 2025-08-07 16:55:36,774 - INFO - Constructing universe for 2022-09-30 using data from 2022-07-29 to 2022-09-29.
# 2025-08-07 16:55:37,070 - INFO - Found 721 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:39,827 - INFO - Initial metrics calculated for 721 tickers. Applying filters...
# 2025-08-07 16:55:39,828 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:39,828 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:39,829 - INFO - 182 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:39,836 - INFO - Final universe DataFrame constructed for 182 stocks with sector data.
# 2025-08-07 16:55:39,847 - INFO - Constructing universe for 2022-10-31 using data from 2022-08-29 to 2022-10-30.
# 2025-08-07 16:55:39,945 - INFO - Found 722 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:41,726 - INFO - Initial metrics calculated for 722 tickers. Applying filters...
# 2025-08-07 16:55:41,727 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:41,727 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:41,728 - INFO - 159 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:41,740 - INFO - Final universe DataFrame constructed for 159 stocks with sector data.
# 2025-08-07 16:55:41,746 - INFO - Constructing universe for 2022-11-30 using data from 2022-09-28 to 2022-11-29.
# 2025-08-07 16:55:41,863 - INFO - Found 722 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:43,853 - INFO - Initial metrics calculated for 722 tickers. Applying filters...
# 2025-08-07 16:55:43,853 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:43,854 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:43,855 - INFO - 142 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:43,860 - INFO - Final universe DataFrame constructed for 142 stocks with sector data.
# 2025-08-07 16:55:43,867 - INFO - Constructing universe for 2022-12-30 using data from 2022-10-28 to 2022-12-29.
# 2025-08-07 16:55:43,975 - INFO - Found 717 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:46,432 - INFO - Initial metrics calculated for 717 tickers. Applying filters...
# 2025-08-07 16:55:46,433 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:46,433 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:46,434 - INFO - 147 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:46,442 - INFO - Final universe DataFrame constructed for 147 stocks with sector data.
# 2025-08-07 16:55:46,449 - INFO - Constructing universe for 2023-01-31 using data from 2022-11-29 to 2023-01-30.
# 2025-08-07 16:55:46,563 - INFO - Found 714 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:48,891 - INFO - Initial metrics calculated for 714 tickers. Applying filters...
# 2025-08-07 16:55:48,892 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:48,893 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:48,894 - INFO - 147 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:48,900 - INFO - Final universe DataFrame constructed for 147 stocks with sector data.
# 2025-08-07 16:55:48,904 - INFO - Constructing universe for 2023-02-28 using data from 2022-12-27 to 2023-02-27.
# 2025-08-07 16:55:49,056 - INFO - Found 712 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:52,069 - INFO - Initial metrics calculated for 712 tickers. Applying filters...
# 2025-08-07 16:55:52,070 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:52,071 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:52,073 - INFO - 145 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:52,084 - INFO - Final universe DataFrame constructed for 145 stocks with sector data.
# 2025-08-07 16:55:52,090 - INFO - Constructing universe for 2023-03-31 using data from 2023-01-27 to 2023-03-30.
# 2025-08-07 16:55:52,274 - INFO - Found 712 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:54,618 - INFO - Initial metrics calculated for 712 tickers. Applying filters...
# 2025-08-07 16:55:54,619 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:54,619 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:54,620 - INFO - 136 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:54,626 - INFO - Final universe DataFrame constructed for 136 stocks with sector data.
# 2025-08-07 16:55:54,633 - INFO - Constructing universe for 2023-04-28 using data from 2023-02-24 to 2023-04-27.
# 2025-08-07 16:55:54,758 - INFO - Found 715 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:56,782 - INFO - Initial metrics calculated for 715 tickers. Applying filters...
# 2025-08-07 16:55:56,783 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:56,783 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:56,785 - INFO - 145 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:56,789 - INFO - Final universe DataFrame constructed for 145 stocks with sector data.
# 2025-08-07 16:55:56,793 - INFO - Constructing universe for 2023-05-31 using data from 2023-03-29 to 2023-05-30.
# 2025-08-07 16:55:56,896 - INFO - Found 717 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:55:58,643 - INFO - Initial metrics calculated for 717 tickers. Applying filters...
# 2025-08-07 16:55:58,643 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:55:58,643 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:55:58,644 - INFO - 166 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:55:58,650 - INFO - Final universe DataFrame constructed for 166 stocks with sector data.
# 2025-08-07 16:55:58,654 - INFO - Constructing universe for 2023-06-30 using data from 2023-04-28 to 2023-06-29.
# 2025-08-07 16:55:58,750 - INFO - Found 717 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:01,500 - INFO - Initial metrics calculated for 717 tickers. Applying filters...
# 2025-08-07 16:56:01,503 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:01,504 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:01,508 - INFO - 186 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:01,522 - INFO - Final universe DataFrame constructed for 186 stocks with sector data.
# 2025-08-07 16:56:01,535 - INFO - Constructing universe for 2023-07-31 using data from 2023-05-29 to 2023-07-30.
# 2025-08-07 16:56:01,775 - INFO - Found 715 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:05,828 - INFO - Initial metrics calculated for 715 tickers. Applying filters...
# 2025-08-07 16:56:05,830 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:05,830 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:05,832 - INFO - 195 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:05,848 - INFO - Final universe DataFrame constructed for 195 stocks with sector data.
# 2025-08-07 16:56:05,859 - INFO - Constructing universe for 2023-08-31 using data from 2023-06-29 to 2023-08-30.
# 2025-08-07 16:56:06,108 - INFO - Found 717 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:09,628 - INFO - Initial metrics calculated for 717 tickers. Applying filters...
# 2025-08-07 16:56:09,629 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:09,629 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:09,630 - INFO - 202 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:09,639 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:56:09,645 - INFO - Constructing universe for 2023-09-29 using data from 2023-07-28 to 2023-09-28.
# 2025-08-07 16:56:09,763 - INFO - Found 716 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:12,355 - INFO - Initial metrics calculated for 716 tickers. Applying filters...
# 2025-08-07 16:56:12,357 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:12,358 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:12,360 - INFO - 205 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:12,374 - INFO - Final universe DataFrame constructed for 200 stocks with sector data.
# 2025-08-07 16:56:12,387 - INFO - Constructing universe for 2023-10-31 using data from 2023-08-29 to 2023-10-30.
# 2025-08-07 16:56:12,574 - INFO - Found 715 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:16,488 - INFO - Initial metrics calculated for 715 tickers. Applying filters...
# 2025-08-07 16:56:16,489 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:16,489 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:16,490 - INFO - 176 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:16,499 - INFO - Final universe DataFrame constructed for 176 stocks with sector data.
# 2025-08-07 16:56:16,505 - INFO - Constructing universe for 2023-11-30 using data from 2023-09-28 to 2023-11-29.
# 2025-08-07 16:56:16,739 - INFO - Found 708 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:19,813 - INFO - Initial metrics calculated for 708 tickers. Applying filters...
# 2025-08-07 16:56:19,814 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:19,815 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:19,817 - INFO - 151 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:19,826 - INFO - Final universe DataFrame constructed for 151 stocks with sector data.
# 2025-08-07 16:56:19,832 - INFO - Constructing universe for 2023-12-29 using data from 2023-10-27 to 2023-12-28.
# 2025-08-07 16:56:19,945 - INFO - Found 710 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:21,658 - INFO - Initial metrics calculated for 710 tickers. Applying filters...
# 2025-08-07 16:56:21,659 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:21,659 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:21,659 - INFO - 151 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:21,665 - INFO - Final universe DataFrame constructed for 151 stocks with sector data.
# 2025-08-07 16:56:21,671 - INFO - Constructing universe for 2024-01-31 using data from 2023-11-29 to 2024-01-30.
# 2025-08-07 16:56:21,771 - INFO - Found 707 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:23,485 - INFO - Initial metrics calculated for 707 tickers. Applying filters...
# 2025-08-07 16:56:23,486 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:23,487 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:23,489 - INFO - 159 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:23,494 - INFO - Final universe DataFrame constructed for 159 stocks with sector data.
# 2025-08-07 16:56:23,498 - INFO - Constructing universe for 2024-02-29 using data from 2023-12-28 to 2024-02-28.
# 2025-08-07 16:56:23,588 - INFO - Found 706 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:25,628 - INFO - Initial metrics calculated for 706 tickers. Applying filters...
# 2025-08-07 16:56:25,630 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:25,630 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:25,632 - INFO - 157 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:25,641 - INFO - Final universe DataFrame constructed for 157 stocks with sector data.
# 2025-08-07 16:56:25,648 - INFO - Constructing universe for 2024-03-29 using data from 2024-01-26 to 2024-03-28.
# 2025-08-07 16:56:25,759 - INFO - Found 713 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:27,549 - INFO - Initial metrics calculated for 713 tickers. Applying filters...
# 2025-08-07 16:56:27,551 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:27,552 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:27,553 - INFO - 168 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:27,559 - INFO - Final universe DataFrame constructed for 168 stocks with sector data.
# 2025-08-07 16:56:27,564 - INFO - Constructing universe for 2024-04-26 using data from 2024-02-23 to 2024-04-25.
# 2025-08-07 16:56:27,671 - INFO - Found 713 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:29,405 - INFO - Initial metrics calculated for 713 tickers. Applying filters...
# 2025-08-07 16:56:29,406 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:29,406 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:29,407 - INFO - 172 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:29,413 - INFO - Final universe DataFrame constructed for 172 stocks with sector data.
# 2025-08-07 16:56:29,419 - INFO - Constructing universe for 2024-05-31 using data from 2024-03-29 to 2024-05-30.
# 2025-08-07 16:56:29,510 - INFO - Found 712 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:31,213 - INFO - Initial metrics calculated for 712 tickers. Applying filters...
# 2025-08-07 16:56:31,215 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:31,217 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:31,218 - INFO - 178 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:31,224 - INFO - Final universe DataFrame constructed for 178 stocks with sector data.
# 2025-08-07 16:56:31,230 - INFO - Constructing universe for 2024-06-28 using data from 2024-04-26 to 2024-06-27.
# 2025-08-07 16:56:31,325 - INFO - Found 711 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:33,061 - INFO - Initial metrics calculated for 711 tickers. Applying filters...
# 2025-08-07 16:56:33,061 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:33,061 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:33,062 - INFO - 191 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:33,068 - INFO - Final universe DataFrame constructed for 191 stocks with sector data.
# 2025-08-07 16:56:33,073 - INFO - Constructing universe for 2024-07-31 using data from 2024-05-29 to 2024-07-30.
# 2025-08-07 16:56:33,191 - INFO - Found 711 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:34,988 - INFO - Initial metrics calculated for 711 tickers. Applying filters...
# 2025-08-07 16:56:34,989 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:34,989 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:34,990 - INFO - 187 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:34,997 - INFO - Final universe DataFrame constructed for 187 stocks with sector data.
# 2025-08-07 16:56:35,004 - INFO - Constructing universe for 2024-08-30 using data from 2024-06-28 to 2024-08-29.
# 2025-08-07 16:56:35,113 - INFO - Found 709 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:36,839 - INFO - Initial metrics calculated for 709 tickers. Applying filters...
# 2025-08-07 16:56:36,839 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:36,840 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:36,841 - INFO - 169 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:36,846 - INFO - Final universe DataFrame constructed for 169 stocks with sector data.
# 2025-08-07 16:56:36,850 - INFO - Constructing universe for 2024-09-30 using data from 2024-07-29 to 2024-09-29.
# 2025-08-07 16:56:37,061 - INFO - Found 707 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:38,950 - INFO - Initial metrics calculated for 707 tickers. Applying filters...
# 2025-08-07 16:56:38,950 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:38,950 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:38,951 - INFO - 153 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:38,956 - INFO - Final universe DataFrame constructed for 153 stocks with sector data.
# 2025-08-07 16:56:38,960 - INFO - Constructing universe for 2024-10-31 using data from 2024-08-29 to 2024-10-30.
# 2025-08-07 16:56:39,071 - INFO - Found 709 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:40,827 - INFO - Initial metrics calculated for 709 tickers. Applying filters...
# 2025-08-07 16:56:40,827 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:40,828 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:40,829 - INFO - 146 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:40,835 - INFO - Final universe DataFrame constructed for 146 stocks with sector data.
# 2025-08-07 16:56:40,839 - INFO - Constructing universe for 2024-11-29 using data from 2024-09-27 to 2024-11-28.
# 2025-08-07 16:56:40,939 - INFO - Found 703 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:42,628 - INFO - Initial metrics calculated for 703 tickers. Applying filters...
# 2025-08-07 16:56:42,629 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:42,629 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:42,630 - INFO - 145 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:42,635 - INFO - Final universe DataFrame constructed for 145 stocks with sector data.
# 2025-08-07 16:56:42,641 - INFO - Constructing universe for 2024-12-31 using data from 2024-10-29 to 2024-12-30.
# 2025-08-07 16:56:42,740 - INFO - Found 702 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:44,393 - INFO - Initial metrics calculated for 702 tickers. Applying filters...
# 2025-08-07 16:56:44,394 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:44,395 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:44,395 - INFO - 158 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:44,402 - INFO - Final universe DataFrame constructed for 158 stocks with sector data.
# 2025-08-07 16:56:44,406 - INFO - Constructing universe for 2025-01-24 using data from 2024-11-22 to 2025-01-23.
# 2025-08-07 16:56:44,524 - INFO - Found 698 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:46,430 - INFO - Initial metrics calculated for 698 tickers. Applying filters...
# 2025-08-07 16:56:46,430 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:46,431 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:46,431 - INFO - 154 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:46,437 - INFO - Final universe DataFrame constructed for 154 stocks with sector data.
# 2025-08-07 16:56:46,443 - INFO - Constructing universe for 2025-02-28 using data from 2024-12-27 to 2025-02-27.
# 2025-08-07 16:56:46,535 - INFO - Found 697 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:48,167 - INFO - Initial metrics calculated for 697 tickers. Applying filters...
# 2025-08-07 16:56:48,168 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:48,168 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:48,169 - INFO - 157 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:48,174 - INFO - Final universe DataFrame constructed for 157 stocks with sector data.
# 2025-08-07 16:56:48,179 - INFO - Constructing universe for 2025-03-31 using data from 2025-01-27 to 2025-03-30.
# 2025-08-07 16:56:48,266 - INFO - Found 699 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:49,926 - INFO - Initial metrics calculated for 699 tickers. Applying filters...
# 2025-08-07 16:56:49,927 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:49,927 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:49,927 - INFO - 163 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:49,932 - INFO - Final universe DataFrame constructed for 163 stocks with sector data.
# 2025-08-07 16:56:49,937 - INFO - Constructing universe for 2025-04-29 using data from 2025-02-25 to 2025-04-28.
# 2025-08-07 16:56:50,044 - INFO - Found 701 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:51,779 - INFO - Initial metrics calculated for 701 tickers. Applying filters...
# 2025-08-07 16:56:51,780 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:51,781 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:51,783 - INFO - 163 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:51,787 - INFO - Final universe DataFrame constructed for 163 stocks with sector data.
# 2025-08-07 16:56:51,791 - INFO - Constructing universe for 2025-05-30 using data from 2025-03-28 to 2025-05-29.
# 2025-08-07 16:56:51,885 - INFO - Found 694 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:53,589 - INFO - Initial metrics calculated for 694 tickers. Applying filters...
# 2025-08-07 16:56:53,589 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:53,590 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:53,591 - INFO - 165 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:53,596 - INFO - Final universe DataFrame constructed for 165 stocks with sector data.
# 2025-08-07 16:56:53,601 - INFO - Constructing universe for 2025-06-30 using data from 2025-04-28 to 2025-06-29.
# 2025-08-07 16:56:53,697 - INFO - Found 696 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:55,384 - INFO - Initial metrics calculated for 696 tickers. Applying filters...
# 2025-08-07 16:56:55,384 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:55,384 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:55,385 - INFO - 165 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:55,390 - INFO - Final universe DataFrame constructed for 165 stocks with sector data.
# 2025-08-07 16:56:55,394 - INFO - Constructing universe for 2025-07-31 using data from 2025-05-29 to 2025-07-30.
# 2025-08-07 16:56:55,492 - INFO - Found 701 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:56:57,138 - INFO - Initial metrics calculated for 701 tickers. Applying filters...
# 2025-08-07 16:56:57,138 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:57,138 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:57,139 - INFO - 180 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:57,144 - INFO - Final universe DataFrame constructed for 180 stocks with sector data.
# 2025-08-07 16:56:57,169 - INFO - Net returns calculated. Total Cost Drag: 12.92%
# 2025-08-07 16:56:57,170 - INFO - Backtest execution complete.
# 2025-08-07 16:56:57,172 - INFO - RUNNING R1 REMEDIATION BACKTEST...
# 2025-08-07 16:56:57,172 - INFO - Starting backtest execution with constructor: score_weighted_beta_constrained
# 2025-08-07 16:56:57,178 - INFO - Generated 67 rebalance dates with frequency 'M'.
# 2025-08-07 16:56:57,181 - INFO - Constructing universe for 2020-01-31 using data from 2019-11-29 to 2020-01-30.
# 2025-08-07 16:56:57,276 - INFO - Found 661 potentially active tickers. Calculating liquidity metrics in batches.
# ✅ Canonical Baseline backtest complete.
#
# ================================================================================
# 2025-08-07 16:56:59,248 - INFO - Initial metrics calculated for 661 tickers. Applying filters...
# 2025-08-07 16:56:59,249 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:56:59,249 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:56:59,250 - INFO - 82 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:56:59,255 - INFO - Final universe DataFrame constructed for 82 stocks with sector data.
# 2025-08-07 16:56:59,263 - WARNING - Insufficient data for beta calculation on 2020-01-31. Defaulting to 1.0.
# 2025-08-07 16:56:59,344 - WARNING - Beta optimization FAILED for 2020-01-31 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:56:59,359 - INFO - Constructing universe for 2020-02-28 using data from 2019-12-27 to 2020-02-27.
# 2025-08-07 16:56:59,534 - INFO - Found 666 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:57:01,454 - INFO - Initial metrics calculated for 666 tickers. Applying filters...
# 2025-08-07 16:57:01,454 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:57:01,455 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:57:01,456 - INFO - 71 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:57:01,464 - INFO - Final universe DataFrame constructed for 71 stocks with sector data.
# 2025-08-07 16:57:01,471 - WARNING - Insufficient data for beta calculation on 2020-02-28. Defaulting to 1.0.
# 2025-08-07 16:57:01,483 - WARNING - Beta optimization FAILED for 2020-02-28 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:57:01,485 - INFO - Constructing universe for 2020-03-31 using data from 2020-01-28 to 2020-03-30.
# 2025-08-07 16:57:01,924 - INFO - Found 674 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:57:03,576 - INFO - Initial metrics calculated for 674 tickers. Applying filters...
# 2025-08-07 16:57:03,576 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:57:03,577 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:57:03,577 - INFO - 79 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:57:03,583 - INFO - Final universe DataFrame constructed for 79 stocks with sector data.
# 2025-08-07 16:57:03,588 - WARNING - Insufficient data for beta calculation on 2020-03-31. Defaulting to 1.0.
# 2025-08-07 16:57:03,593 - WARNING - Beta optimization FAILED for 2020-03-31 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:57:03,595 - INFO - Constructing universe for 2020-04-29 using data from 2020-02-26 to 2020-04-28.
# 2025-08-07 16:57:03,694 - INFO - Found 676 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:57:05,543 - INFO - Initial metrics calculated for 676 tickers. Applying filters...
# 2025-08-07 16:57:05,544 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:57:05,544 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:57:05,545 - INFO - 86 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:57:05,553 - INFO - Final universe DataFrame constructed for 86 stocks with sector data.
# 2025-08-07 16:57:05,580 - INFO - Constructing universe for 2020-05-29 using data from 2020-03-27 to 2020-05-28.
# 2025-08-07 16:57:05,698 - INFO - Found 673 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:57:07,909 - INFO - Initial metrics calculated for 673 tickers. Applying filters...
# ...
# 2025-08-07 16:59:15,961 - WARNING - Beta optimization FAILED for 2023-09-29 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:15,963 - INFO - Constructing universe for 2023-10-31 using data from 2023-08-29 to 2023-10-30.
# 2025-08-07 16:59:16,059 - INFO - Found 715 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:17,769 - INFO - Initial metrics calculated for 715 tickers. Applying filters...
# 2025-08-07 16:59:17,769 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:17,769 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:17,771 - INFO - 176 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:17,776 - INFO - Final universe DataFrame constructed for 176 stocks with sector data.
# 2025-08-07 16:59:17,801 - WARNING - Beta optimization FAILED for 2023-10-31 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:17,804 - INFO - Constructing universe for 2023-11-30 using data from 2023-09-28 to 2023-11-29.
# 2025-08-07 16:59:17,906 - INFO - Found 708 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:19,558 - INFO - Initial metrics calculated for 708 tickers. Applying filters...
# 2025-08-07 16:59:19,559 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:19,560 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:19,561 - INFO - 151 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:19,567 - INFO - Final universe DataFrame constructed for 151 stocks with sector data.
# 2025-08-07 16:59:19,592 - INFO - Constructing universe for 2023-12-29 using data from 2023-10-27 to 2023-12-28.
# 2025-08-07 16:59:19,681 - INFO - Found 710 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:21,355 - INFO - Initial metrics calculated for 710 tickers. Applying filters...
# 2025-08-07 16:59:21,355 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:21,355 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:21,356 - INFO - 151 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:21,362 - INFO - Final universe DataFrame constructed for 151 stocks with sector data.
# 2025-08-07 16:59:21,380 - WARNING - Beta optimization FAILED for 2023-12-29 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:21,383 - INFO - Constructing universe for 2024-01-31 using data from 2023-11-29 to 2024-01-30.
# 2025-08-07 16:59:21,475 - INFO - Found 707 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:23,167 - INFO - Initial metrics calculated for 707 tickers. Applying filters...
# 2025-08-07 16:59:23,168 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:23,169 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:23,170 - INFO - 159 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:23,175 - INFO - Final universe DataFrame constructed for 159 stocks with sector data.
# 2025-08-07 16:59:23,194 - WARNING - Beta optimization FAILED for 2024-01-31 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:23,197 - INFO - Constructing universe for 2024-02-29 using data from 2023-12-28 to 2024-02-28.
# 2025-08-07 16:59:23,284 - INFO - Found 706 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:25,223 - INFO - Initial metrics calculated for 706 tickers. Applying filters...
# 2025-08-07 16:59:25,225 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:25,225 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:25,226 - INFO - 157 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:25,236 - INFO - Final universe DataFrame constructed for 157 stocks with sector data.
# 2025-08-07 16:59:25,263 - WARNING - Beta optimization FAILED for 2024-02-29 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:25,266 - INFO - Constructing universe for 2024-03-29 using data from 2024-01-26 to 2024-03-28.
# 2025-08-07 16:59:25,367 - INFO - Found 713 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:27,247 - INFO - Initial metrics calculated for 713 tickers. Applying filters...
# 2025-08-07 16:59:27,250 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:27,251 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:27,252 - INFO - 168 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:27,258 - INFO - Final universe DataFrame constructed for 168 stocks with sector data.
# 2025-08-07 16:59:27,282 - WARNING - Beta optimization FAILED for 2024-03-29 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:27,284 - INFO - Constructing universe for 2024-04-26 using data from 2024-02-23 to 2024-04-25.
# 2025-08-07 16:59:27,380 - INFO - Found 713 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:29,100 - INFO - Initial metrics calculated for 713 tickers. Applying filters...
# 2025-08-07 16:59:29,101 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:29,101 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:29,102 - INFO - 172 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:29,115 - INFO - Final universe DataFrame constructed for 172 stocks with sector data.
# 2025-08-07 16:59:29,140 - WARNING - Beta optimization FAILED for 2024-04-26 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:29,143 - INFO - Constructing universe for 2024-05-31 using data from 2024-03-29 to 2024-05-30.
# 2025-08-07 16:59:29,242 - INFO - Found 712 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:31,033 - INFO - Initial metrics calculated for 712 tickers. Applying filters...
# 2025-08-07 16:59:31,034 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:31,034 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:31,035 - INFO - 178 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:31,042 - INFO - Final universe DataFrame constructed for 178 stocks with sector data.
# 2025-08-07 16:59:31,071 - INFO - Constructing universe for 2024-06-28 using data from 2024-04-26 to 2024-06-27.
# 2025-08-07 16:59:31,229 - INFO - Found 711 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:33,201 - INFO - Initial metrics calculated for 711 tickers. Applying filters...
# 2025-08-07 16:59:33,207 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:33,207 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:33,211 - INFO - 191 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:33,225 - INFO - Final universe DataFrame constructed for 191 stocks with sector data.
# 2025-08-07 16:59:33,280 - INFO - Constructing universe for 2024-07-31 using data from 2024-05-29 to 2024-07-30.
# 2025-08-07 16:59:33,400 - INFO - Found 711 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:35,235 - INFO - Initial metrics calculated for 711 tickers. Applying filters...
# 2025-08-07 16:59:35,236 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:35,236 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:35,240 - INFO - 187 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:35,247 - INFO - Final universe DataFrame constructed for 187 stocks with sector data.
# 2025-08-07 16:59:35,275 - INFO - Constructing universe for 2024-08-30 using data from 2024-06-28 to 2024-08-29.
# 2025-08-07 16:59:35,375 - INFO - Found 709 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:37,171 - INFO - Initial metrics calculated for 709 tickers. Applying filters...
# 2025-08-07 16:59:37,172 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:37,173 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:37,174 - INFO - 169 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:37,179 - INFO - Final universe DataFrame constructed for 169 stocks with sector data.
# 2025-08-07 16:59:37,195 - WARNING - Beta optimization FAILED for 2024-08-30 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:37,197 - INFO - Constructing universe for 2024-09-30 using data from 2024-07-29 to 2024-09-29.
# 2025-08-07 16:59:37,292 - INFO - Found 707 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:39,130 - INFO - Initial metrics calculated for 707 tickers. Applying filters...
# 2025-08-07 16:59:39,131 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:39,131 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:39,132 - INFO - 153 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:39,139 - INFO - Final universe DataFrame constructed for 153 stocks with sector data.
# 2025-08-07 16:59:39,164 - INFO - Constructing universe for 2024-10-31 using data from 2024-08-29 to 2024-10-30.
# 2025-08-07 16:59:39,264 - INFO - Found 709 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:41,015 - INFO - Initial metrics calculated for 709 tickers. Applying filters...
# 2025-08-07 16:59:41,015 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:41,015 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:41,017 - INFO - 146 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:41,027 - INFO - Final universe DataFrame constructed for 146 stocks with sector data.
# 2025-08-07 16:59:41,056 - INFO - Constructing universe for 2024-11-29 using data from 2024-09-27 to 2024-11-28.
# 2025-08-07 16:59:41,155 - INFO - Found 703 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:43,071 - INFO - Initial metrics calculated for 703 tickers. Applying filters...
# 2025-08-07 16:59:43,072 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:43,072 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:43,073 - INFO - 145 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:43,079 - INFO - Final universe DataFrame constructed for 145 stocks with sector data.
# 2025-08-07 16:59:43,093 - WARNING - Beta optimization FAILED for 2024-11-29 (status: infeasible). Returning unconstrained weights.
# 2025-08-07 16:59:43,096 - INFO - Constructing universe for 2024-12-31 using data from 2024-10-29 to 2024-12-30.
# 2025-08-07 16:59:43,270 - INFO - Found 702 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:45,381 - INFO - Initial metrics calculated for 702 tickers. Applying filters...
# 2025-08-07 16:59:45,382 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:45,382 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:45,383 - INFO - 158 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:45,390 - INFO - Final universe DataFrame constructed for 158 stocks with sector data.
# 2025-08-07 16:59:45,416 - INFO - Constructing universe for 2025-01-24 using data from 2024-11-22 to 2025-01-23.
# 2025-08-07 16:59:45,527 - INFO - Found 698 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:47,259 - INFO - Initial metrics calculated for 698 tickers. Applying filters...
# 2025-08-07 16:59:47,259 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:47,259 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:47,260 - INFO - 154 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:47,265 - INFO - Final universe DataFrame constructed for 154 stocks with sector data.
# 2025-08-07 16:59:47,281 - INFO - Constructing universe for 2025-02-28 using data from 2024-12-27 to 2025-02-27.
# 2025-08-07 16:59:47,369 - INFO - Found 697 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:49,105 - INFO - Initial metrics calculated for 697 tickers. Applying filters...
# 2025-08-07 16:59:49,105 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:49,105 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:49,106 - INFO - 157 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:49,114 - INFO - Final universe DataFrame constructed for 157 stocks with sector data.
# 2025-08-07 16:59:49,135 - INFO - Constructing universe for 2025-03-31 using data from 2025-01-27 to 2025-03-30.
# 2025-08-07 16:59:49,227 - INFO - Found 699 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:50,987 - INFO - Initial metrics calculated for 699 tickers. Applying filters...
# 2025-08-07 16:59:50,987 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:50,988 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:50,988 - INFO - 163 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:50,993 - INFO - Final universe DataFrame constructed for 163 stocks with sector data.
# 2025-08-07 16:59:51,013 - INFO - Constructing universe for 2025-04-29 using data from 2025-02-25 to 2025-04-28.
# 2025-08-07 16:59:51,110 - INFO - Found 701 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:52,810 - INFO - Initial metrics calculated for 701 tickers. Applying filters...
# 2025-08-07 16:59:52,810 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:52,810 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:52,811 - INFO - 163 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:52,817 - INFO - Final universe DataFrame constructed for 163 stocks with sector data.
# 2025-08-07 16:59:52,841 - INFO - Constructing universe for 2025-05-30 using data from 2025-03-28 to 2025-05-29.
# 2025-08-07 16:59:52,945 - INFO - Found 694 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:54,648 - INFO - Initial metrics calculated for 694 tickers. Applying filters...
# 2025-08-07 16:59:54,649 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:54,650 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:54,652 - INFO - 165 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:54,657 - INFO - Final universe DataFrame constructed for 165 stocks with sector data.
# 2025-08-07 16:59:54,676 - INFO - Constructing universe for 2025-06-30 using data from 2025-04-28 to 2025-06-29.
# 2025-08-07 16:59:54,776 - INFO - Found 696 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:56,470 - INFO - Initial metrics calculated for 696 tickers. Applying filters...
# 2025-08-07 16:59:56,471 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:56,471 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:56,472 - INFO - 165 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:56,480 - INFO - Final universe DataFrame constructed for 165 stocks with sector data.
# 2025-08-07 16:59:56,532 - INFO - Constructing universe for 2025-07-31 using data from 2025-05-29 to 2025-07-30.
# 2025-08-07 16:59:56,633 - INFO - Found 701 potentially active tickers. Calculating liquidity metrics in batches.
# 2025-08-07 16:59:58,290 - INFO - Initial metrics calculated for 701 tickers. Applying filters...
# 2025-08-07 16:59:58,290 - INFO -   - Trading days threshold: >= 37
# 2025-08-07 16:59:58,291 - INFO -   - ADTV threshold: >= 10.0B VND
# 2025-08-07 16:59:58,292 - INFO - 180 stocks passed filters. Selecting top 200 by ADTV.
# 2025-08-07 16:59:58,297 - INFO - Final universe DataFrame constructed for 180 stocks with sector data.
# 2025-08-07 16:59:58,349 - INFO - Net returns calculated. Total Cost Drag: 16.14%
# 2025-08-07 16:59:58,350 - INFO - Backtest execution complete.
# /var/folders/rb/_5jyx5gx6vn69mhckz6xq6040000gn/T/ipykernel_70959/873330136.py:113: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.03, 1, 0.96])
# ✅ R1 Remediation backtest complete.
#
# ================================================================================
# 📊 GENERATING COMPARATIVE PERFORMANCE REPORT...
# ================================================================================
